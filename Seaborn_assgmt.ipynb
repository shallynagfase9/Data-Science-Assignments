# %% [markdown]
# <a href="https://colab.research.google.com/github/shallynagfase9/Data-Science-Assignments/blob/main/Seaborn_assgmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
'''
Histogram
Bar chart
Lineplot
Scatter pot
Pairplot
'''

# %%
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x ="timepoint" and y = "signal" for different events and regions.
import seaborn as sns
fmri = sns.load_dataset("fmri")
sns.lineplot(x ="timepoint", y = "signal", data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.
titanic = sns.load_dataset("titanic")
sns.boxplot(x ='pclass',y = 'age',data = titanic)
sns.boxplot(x ='pclass',y = 'fare',data = titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.
diamonds = sns.load_dataset("diamonds")
sns.histplot(x='price',hue = "cut", data=diamonds)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.
iris = sns.load_dataset("iris")
sns.pairplot(x_vars=["sepal_length","sepal_width","petal_length","petal_width"],y_vars=["species"],hue="species",data=iris)

# %%
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
flights = sns.load_dataset("flights")
flights.head()
flights_pivot = flights.pivot("month", "year", "passengers")

sns.heatmap(flights_pivot, cmap='Blues', annot=True, fmt='d')
# Out:
# <ipython-input-15-a5ffaab3957f>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot = flights.pivot("month", "year", "passengers")
# <Axes: xlabel='year', ylabel='month'>
